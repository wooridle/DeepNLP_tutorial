# %% [markdown]
# <h1>word2vec with naver movie comments</h1>

# %% [markdown]
# #### word2vec을 쉽게 구현할 수 있는 라이브러리 gensim

# %%
import numpy as np
import pandas as pd
import gensim

# %% [markdown]
# ### 네이버 영화 리뷰 데이터 불러오기

# %%
train = pd.read_csv('ratings_train.txt', delimiter='\t')
test = pd.read_csv('ratings_test.txt', delimiter='\t')

# %% [markdown]
# ### 이전에 전처리하였던 데이터(Numpy array)를 불러와 재사용 합니다.

# %% [markdown]
# 미리 전처리된 데이터를 numpy array형태로 저장하면 그대로 불러와 사용하면 되므로 편리합니다.

# %%
train_segs = np.load('train_segs.npy')
train_sents = np.load('train_sents.npy')

# %%
train_segs
# Out:
# array([['아', '더빙', '..', '진짜', '짜증', '나네', '요', '목소리'],
#        ['흠', '...', '포스터', '보고', '초딩', '영화', '줄', '....', '오버', '연기', '조차', '가볍', '지', '않구', '나'],
#        ['너무', '재', '밓었', '다', '그래서', '보는', '것', '을', '추천한', '다'], ...,
#        ['이', '게', '뭐', '요', '?', '한국인', '은', '거들', '먹거리', '고', '필리핀', '혼혈', '은', '착하다', '?'],
#        ['청춘', '영화', '의', '최고봉', '.', '방황', '과', '우울했', '던', '날', '들', '의', '자화상'],
#        ['한국', '영화', '최초', '로', '수간', '하는', '내용', '이', '담긴', '영화']], dtype=object)

# %% [markdown]
# ### Gensim을 사용하여 Word2vec 모델을 생성합니다.

# %%
model = gensim.models.Word2Vec(min_count=2, window=5, size=300)

# %%
model.build_vocab(train_segs)

# %%
model.train(train_segs, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ac413a88e756> in <module>()
# ----> 1 model.train(train_segs, total_examples=model.corpus_count, epochs=model.epochs)
#
# AttributeError: 'Word2Vec' object has no attribute 'epochs'

# %%
word_vectors = model.wv

# %%
len(word_vectors.vocab)
# Out:
# 34371

# %%
word_vectors.most_similar(positive=['광해', '황정민'], negative=['이병헌'])
# Out:
# [('날조', 0.24256309866905212),
#  ('푹푹', 0.23636221885681152),
#  ('상회', 0.22630561888217926),
#  ('우린', 0.2156609445810318),
#  ('가필드', 0.2124473601579666),
#  ('흐뭇하고', 0.20888115465641022),
#  ('바늘', 0.206259086728096),
#  ('일렁이', 0.20411193370819092),
#  ('진입', 0.20212914049625397),
#  ('닠', 0.19976484775543213)]

# %% [markdown]
# ### Word2vec 모델을 바이너리 파일로 저장합니다.

# %% [markdown]
# 바이너리 파일로 저장하면 나중에 워드 임베딩이 필요하면 로드하여 사용할 수 있습니다.

# %%
model.save('./vectors.bin')

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(ngram_range=(1,1), min_df=2).fit(train_sents.astype('U'))

# %%
print(len(vect.vocabulary_))
# Out:
# 31455

# %%
vect.inverse_vocabulary_ = {vect.vocabulary_[k] : k for k in vect.vocabulary_}

# %%
vect.vocabulary_.keys()
#{'더빙': 16437,
#'진짜': 59534,
#'짜증나네요': 59954,
#'목소리': 23329,
#'포스터보고': 65489, ...}
# Out:
# dict_keys(['더빙', '진짜', '짜증', '나네', '목소리', '포스터', '보고', '초딩', '영화', '오버', '연기', '조차', '가볍', '않구', '너무', '그래서', '보는', '추천한', '교도소', '이야기', '구먼', '솔직히', '재미', '없다', '평점', '조정', '익살', '스런', '돋보였', '스파이더맨', '에서', '늙어', '보이', '기만', '스틴', '던스트', '너무나', '이뻐', '보였', '걸음', '부터', '초등학교', '학년', '생인', 'ㅋㅋㅋ', '별반', '아까', '원작', '긴장감', '제대로', '살려', '반개', '아깝', '나온', '이응경', '길용우', '생활', '인지', '정말', '해도', '그것', '보단', '납치', '감금', '반복', '드라마', '가족', '하는', '사람', '액션', '없는', '데도', '있는', '안되는', '왜케', '낮은', '건데', '헐리우드', '화려함', '에만', '들여', '인피니트', '이다', '볼때', '마다', '눈물', '나서', '죽겠', '90', '년대', '향수', '자극', '허진호', '감성', '절제', '멜로', '달인', '울면', '이범수', '드럽게못', '하고', '깔끔해서', '신문', '기사', '로만', '보다', '보면', '자꾸', '잊어버린', '이었', '다는', '취향', '지만', '내생', '극장', '가장', '노잼', '감동', '스토리', '어거지', '매번', '긴장되', '재밋음', 'ㅠㅠ', '웃긴', '바스코', '이기', '락스', '라고', '까고', '바비', '아이돌', '이라고', '그냥', '어서', '안달', '처럼', '보인', '굿바이', '레닌', '표절', '이해하는', '갈수록', '이건', '깨알', '캐스팅', '질퍽', '하지', '않은', '뜻한', '용구성', '버무러진', '일드', '약탈', '위한', '변명', '이라', '착한', '절대', '아닌', '나름', '심오', '학생', '선생', '놀아', '아님', '웃지', '않는', '불가능하다', '재미없', '지루하고', '같은', '음식', '인데', '만찬', '차이', '있고', '볼게', '별로', '나오고', '핀란드', '풍경', '이라도', '구경할', '나옴', 'ㅡㅡ', '평범한', '수작', '는걸', '말씀드립니', '주제', '은데', '중반', '지루하다', '납득할', '없었', '거야', '그럴', '그랬', '던걸', '고추', '털어', '버려', '텐데', '카밀라', '발연기', '센스', '연출', '탁월한', '엄포', '위력', '다시', '한번', '깨닫', '해준', '검사', '어요', '완전', '명품', '쓰레기', '진부', '도안', 'ㅋㅋ', '시간', '아까워', '재밌는', '별점', '이리', '라도', '기대했', '죄인', '입니', '아직', '인생', '최고', '패션', '대한', '열정', '안나', '투어', '키이라', '나이틀리', '연기하고', '대체', '정신장애', '틱장애', '허허', '정신', '나간', '유령', '재미있겠', '네요', '있어', '보이는', '관객', '114', '이네', '이렇게', '평가', '받는', '모르', '단순하면', '은은한', '매력', '알바생', '인가', '내용', '없고', '무서운', '하나', '싱거운', '낚임', '오게', '두어', '서리', '들어', '방법', '없네', 'ㅜㅡ', '윤제문', '이라는', '멋진', '배우', '발견하게', '소소한', '일탈', '잔잔', '미소', '머금', '니다', '음악', '조금', '아쉽', '주고', '싶은', '올리', '싶어', '10', '게요', '속지', '마시', '낭비', '리얼리티', '한데', '공감', '간다', '이민기', '캐릭터', '분노조절', '장애', '초기', '증상', '툭하면', '욕하고', '물건', '파손', '오바', '초반', '신선했', '는데', '가면', '상태', '불가', '마이너스', '없냐', '뮤비', '수준', '하더', 'ㅉㅉ', '북한', '이런', '만들', '우리', '사랑합', '리스', '타르', '가르', '나도', '용의', '주인', '싶다', '이랑', '근친상간', '이나', '다닐', '소설', '에선', '제일', '니스', '드래곤', '멋지', '웃음', '감독', '토르', '다크', '월드', '잡수셨', '을지라도', '기본', '선방', '영혼', '어루만져', '수도', '군요', '거친', '상사', '잠시', '잊고', '동화', '행복했', '세르게이', '작은', '매운', '보여', '저그', '진호', '가슴', '시리', '을까', '자체', '난또', '꼬마', '애가', '무슨', '원한', '더니', 'oo', '혼자', '나대다', '어쩌라고', '재미있어', '아요', '충격', '엇다', '기분', '완전히', '꺼지', '느낌', '이라고는', '무거운', '지독', '차갑', '무자비', '하다', '그저', '일본인', '상상력', '대단한', '같다', '생각', '심심한', '언제', '나오', '나요', '그대로', '맞는', '예측', '카리스마', '악역', '불알', '나와', '당황', '아무튼', '중간', '끝나는', '평범함', '녹아', '일상', '밋밋한', '보던', '계속', '전개도', '느리', '주인공', '은희', '나오면', '소극', '모습', 'ㅜㅜ', '맨날', '끝나', '기대', '전개', '빨리', '사랑하고', '싶게', '가슴속', '감정', '헤집', '예요', '많은', '다큐', '우리나라', '슬픈', '현대', '사의', '단면', '대해', '깊이', '생각하고', '사죄', '바로', '잡기', '위해', '노력했', '으면', '말로', '듣던', '보도', '민간인', '학살', '이정', '이야', '명백', '살인', '살인자', '어디', '예전', '작품', '에피소드', '재탕', '삼탕', '사골', '우려', '먹듯', '으로', '가고', '시청률', '아예', '이제', '70', '120', '부작', '이라니', '김남길', '백점', '연기력', '몰입도', '에도', '불구하고', '손예진', 'ㅈㅈ', '재밌네', '비슷한', '보신', '한테', '재미있', '노래실력', '뽑는', '맞냐', '박시환', 'mama', '나가면', '망신', '일본', '건가', '유치', '이틀', '만에', '재밌어', '근데', '넣어', '조작', '하려', '하면', '안이', '열려', '던지', '활짝', '들어간', '던가', '문자', '비번', '걸려', '그런', '억지', '스러웠', '그래도', '졸작', '재밋네', '달팽이', '라서', '재밌었', '어설픈', '어이', '결말', '부패', '로마노프', '왕조', '기리', '뭣같', '온몸', '항거', '러시아', '민중', '폭도', '무난', '보았', '습니다', '매우', '실망', '한국영', '흥행', '코드', '갈등', '화해', '남발', '뻔하지', '아햏햏', '시작하고', '분만', '나왔', '사진', '보며', '불안하', '더니만', '단연', '먹고', '만들었', '에게', '말하는', '지도', '엉망', '진창', '우뢰매', '진정', '위대한', '별루', '내일', '기대되는', '조미', '막문위', '좋아한', '가요', '부라', '성룡', '최악', '때리', 'ㅋㅋㅋㅋ', '걸스데이', '서기', 'ㅋㅋㅋㅋㅋ', '백인', '공주', '귀여', 'ㅋㅋㅋㅋㅋㅋ', '인상', '셀레스틴', '강추', '에요', '재밌', '재미있는', '클라라', '볼라', '화신', '슬펐', '설정', '재밌고', '새로운', '메인', '차차', '나오는', '신카이', '마코토', '작화', '카나', '잘해', '대박' ...
